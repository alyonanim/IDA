# %% [markdown]
# # Домашнее задание 2 (5 баллов).
#
# Все задания ниже имеют равный вес (5/16).

# %%
import pandas as pd
import os

# %%
# !wget https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# !unzip /content/Data.zip
# Out:
# --2024-02-07 15:07:29--  https://github.com/hse-ds/iad-intro-ds/raw/master/2023/homeworks/Data.zip
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip [following]
# --2024-02-07 15:07:30--  https://raw.githubusercontent.com/hse-ds/iad-intro-ds/master/2023/homeworks/Data.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16727 (16K) [application/zip]
# Saving to: ‘Data.zip’
#
# Data.zip            100%[===================>]  16.33K  --.-KB/s    in 0s
#
# 2024-02-07 15:07:30 (33.7 MB/s) - ‘Data.zip’ saved [16727/16727]
#
# ...

# %% [markdown]
# #### Описание данных
#
# В папке Dat (https://github.com/hse-ds/iad-intro-ds/blob/master/2023/homeworks/Data.zip) находится информация о студентах. Всего 10 групп студентов. Файлы делятся на две категории:
#     * Students_info_i - информация о студентах из группы i
#     * Students_marks_i - оценки студентов из группы i за экзамены

# %% [markdown]
# ### Одно из важных достоинств pandas $-$ это удобные методы реляционного взаимодействия с данными, аналогичные, например, возможностям SQL для слияния и конкатенации таблиц: merge, join, concat. Наличие готовых методов позволяет не реализовывать самостоятельно поэлементную обработку данных и оперировать сразу целыми таблицами данных.
#
# Подробно об этих методах посмотрите тут: https://www.kaggle.com/residentmario/renaming-and-combining#Combining

# %% [markdown]
# #### Задание 1. Соберите всю информацию о студентах в одну таблицу df. В получившейся таблице должна быть информация и оценки всех студентов из всех групп. Напечатайте несколько строк таблицы для демонстрации результата.¶

# %%
#Загрузка данных по студентам
Students_info_0 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_0.csv'))
Students_info_1 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_1.csv'))
Students_info_2 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_2.csv'))
Students_info_3 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_3.csv'))
Students_info_4 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_4.csv'))
Students_info_5 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_5.csv'))
Students_info_6 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_6.csv'))
Students_info_7 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_7.csv'))
Students_info_8 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_8.csv'))
Students_info_9 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_info_9.csv'))

# %%
#Объединяем информацию в один DataFrame
df_info = pd.concat([Students_info_0, Students_info_1, Students_info_2, Students_info_3, Students_info_4,
                    Students_info_5, Students_info_6, Students_info_7, Students_info_8, Students_info_9], axis=0)
df_info.head()
# Out:
#    index  gender race/ethnicity parental level of education         lunch  \
# 0      0  female        group B           bachelor's degree      standard
# 1      1  female        group C                some college      standard
# 2      2  female        group B             master's degree      standard
# 3      3    male        group A          associate's degree  free/reduced
# 4      4    male        group C                some college      standard
#
#   test preparation course   group
# 0                    none  group1
# 1               completed  group1
# 2                    none  group1
# 3                    none  group1
# 4                    none  group1

# %%
#Загрузка оценок студентов
Students_marks_0 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_0.csv'))
Students_marks_1 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_1.csv'))
Students_marks_2 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_2.csv'))
Students_marks_3 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_3.csv'))
Students_marks_4 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_4.csv'))
Students_marks_5 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_5.csv'))
Students_marks_6 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_6.csv'))
Students_marks_7 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_7.csv'))
Students_marks_8 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_8.csv'))
Students_marks_9 = pd.read_csv(os.path.join(os.path.abspath('Data'), 'Students_marks_9.csv'))
Students_marks_0.head()
# Out:
#    index  math score  reading score  writing score
# 0      0          72             72             74
# 1      1          69             90             88
# 2      2          90             95             93
# 3      3          47             57             44
# 4      4          76             78             75

# %%
#Объединяем оценки в один DataFrame
df_marks = pd.concat([Students_marks_0,  Students_marks_1, Students_marks_2, Students_marks_3, Students_marks_4, Students_marks_5,
                Students_marks_6, Students_marks_7, Students_marks_8, Students_marks_9], axis=0)
df_marks.head()
# Out:
#    index  math score  reading score  writing score
# 0      0          72             72             74
# 1      1          69             90             88
# 2      2          90             95             93
# 3      3          47             57             44
# 4      4          76             78             75

# %%
#Объединяем информацию и оценки в одну таблицу
df = pd.merge(df_info, df_marks, on="index", how="outer")
df.head()
# Out:
#    index  gender race/ethnicity parental level of education         lunch  \
# 0      0  female        group B           bachelor's degree      standard
# 1      1  female        group C                some college      standard
# 2      2  female        group B             master's degree      standard
# 3      3    male        group A          associate's degree  free/reduced
# 4      4    male        group C                some college      standard
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# 2                    none  group1          90             95             93
# 3                    none  group1          47             57             44
# 4                    none  group1          76             78             75

# %% [markdown]
# #### Задание 2. Удалите столбец index у полученной таблицы. Напечатайте первые 10 строк таблицы.

# %%
df = df.drop('index', axis = 1)
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course   group  math score  reading score  writing score
# 0                    none  group1          72             72             74
# 1               completed  group1          69             90             88
# ...

# %% [markdown]
# #### Задание 3. Выведите на экран размеры полученной таблицы

# %%
df.shape
# Out:
# (1000, 9)

# %%
print(f'Количество строк: {df.shape[0]}')
print(f'Количество столбцов: {df.shape[1]}')
# Out:
# Количество строк: 1000
# Количество столбцов: 9

# %% [markdown]
# #### Задание 4. Выведите на экран статистические характеристики числовых столбцов таблицы (минимум, максимум, среднее значение, стандартное отклонение)

# %% [markdown]
# Посмотрим все характеристики сразу

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# Посмотреть статистические характеристики отдельно

# %%
df.min(numeric_only=True)
# Out:
# math score        0
# reading score    17
# writing score    10
# dtype: int64

# %%
df.max(numeric_only=True)
# Out:
# math score       100
# reading score    100
# writing score    100
# dtype: int64

# %%
df.mean(numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %%
df.std(numeric_only=True)
# Out:
# math score       15.163080
# reading score    14.600192
# writing score    15.195657
# dtype: float64

# %% [markdown]
# #### Задание 5. Проверьте, есть ли в таблице пропущенные значения

# %%
#Количество пропущенных значений по столбцам
df.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# group                          0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %% [markdown]
# Ответ: пропущенных значений нет ни в одном столбце

# %% [markdown]
# #### Задание 6. Выведите на экран средние баллы студентов по каждому предмету (math, reading, writing)

# %%
df.mean(numeric_only=True)
# Out:
# math score       66.089
# reading score    69.169
# writing score    68.054
# dtype: float64

# %% [markdown]
# **Задание 7. Как зависят оценки от того, проходил ли студент курс для подготовки к сдаче экзамена (test preparation course)? Выведите на экран для каждого предмета в отдельности средний балл студентов, проходивших курс для подготовки к экзамену и не проходивших курс.**

# %%
#возможные значения столбца test preparation course
df['test preparation course'].unique()
# Out:
# array(['none', 'completed'], dtype=object)

# %%
#Средний балл по каждому предмету студентов, которые проходили курс
print(df[df['test preparation course'] == 'completed'].mean(numeric_only = True))
# Out:
# math score       69.695531
# reading score    73.893855
# writing score    74.418994
# dtype: float64

# %%
#Средний балл по каждому предмету студентов, которые не проходили курс
print(df[df['test preparation course'] == 'none'].mean(numeric_only = True))
# Out:
# math score       64.077882
# reading score    66.534268
# writing score    64.504673
# dtype: float64

# %% [markdown]
# Вывод: в среднем, оценки студентов, которые проходили курс по подготовке к экзамену выше, но незначительно - разница максимум в один балл. Больше всего курсы помогли по письму - средняя оценка проходивших курс выше на 1 балл.

# %% [markdown]
# **Задание 8. Выведите на экран все различные значения из столбца lunch.**

# %%
print('Уникальные значения в столбце lunch:', df['lunch'].unique())
# Out:
# Уникальные значения в столбце lunch: ['standard' 'free/reduced']

# %% [markdown]
# **Задание 9. Переименуйте колонку "parental level of education" в "education", а "test preparation course" в "test preparation" с помощью метода pandas rename**
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html

# %%
df = df.rename(columns={'parental level of education': 'education', 'test preparation course': 'test preparation'})

# %%
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score
# 0  group1          72             72             74
# 1  group1          69             90             88
# 2  group1          90             95             93
# 3  group1          47             57             44
# 4  group1          76             78             75

# %% [markdown]
# **Зафиксируем минимальный балл для сдачи экзамена**

# %%
passmark = 50

# %% [markdown]
# **Задание 10. Ответьте на вопросы:**
#     * Какая доля студентов сдала экзамен по математике (passmark >= 50)?
#     * Какая доля студентов, проходивших курс подготовки к экзамену, сдала экзамен по математике?
#     * Какая доля женщин, не проходивших курс подготовки к экзамену, не сдала экзамен по математике?

# %%
print('Доля студентов, сдавших экзамен по математике:', (df['math score'] >= passmark).sum() / df.shape[0])
# Out:
# Доля студентов, сдавших экзамен по математике: 0.865

# %%
print('Доля студентов, проходивших курс подготовки к экзамену, которые сдали экзамен по математике:',
 ((df['math score'] >= passmark) & (df['test preparation'] == 'completed')).sum() / (df['test preparation'] == 'completed').sum())
# Out:
# Доля студентов, проходивших курс подготовки к экзамену, которые сдали экзамен по математике: 0.9217877094972067

# %%
print('Доля женщин, не проходивших курс подготовки к экзамену, которые не сдали экзамен по математике',
 ((df['gender'] == 'female') & (df['test preparation'] == 'none') & (df['math score'] < passmark)).sum() / ((df['gender'] == 'female') & (df['test preparation'] == 'none')).sum())
# Out:
# Доля женщин, не проходивших курс подготовки к экзамену, которые не сдали экзамен по математике 0.20958083832335328

# %% [markdown]
# **Задание 11. С помощью groupby выполните задания ниже. Также выведите время выполнения каждого из заданий.**
#     * Для каждой этнической группы выведите средний балл за экзамен по чтению
#     * Для каждого уровня образования выведите минимальный балл за экзамен по письму

# %%
#средний балл за экзамен по чтению для каждой этнической группы
df.groupby(['race/ethnicity']).agg({'reading score': ['mean']})
# Out:
#                reading score
#                         mean
# race/ethnicity
# group A            64.674157
# group B            67.352632
# group C            69.103448
# group D            70.030534
# group E            73.028571

# %%
# %%timeit
df.groupby(['race/ethnicity']).agg({'reading score': ['mean']})
# Out:
# 1.62 ms ± 191 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
#минимальный балл за экзамен по письму для каждого уровня образования
df.groupby(['education']).agg({'writing score': ['min']})
# Out:
#                    writing score
#                              min
# education
# associate's degree            35
# bachelor's degree             38
# high school                   15
# master's degree               46
# some college                  19
# some high school              10

# %%
# %%timeit
df.groupby(['education']).agg({'writing score': ['min']})
# Out:
# 1.67 ms ± 232 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# **Задание 12. Выполните задание 11 с помощью циклов. Сравните время выполнения.**

# %%
#средний балл за экзамен по чтению для каждой этнической группы
groups = sorted(list(df['race/ethnicity'].unique()))
d_sumscore = {}
d_cnt = {}
for group in groups:
    d_sumscore[group] = 0
    d_cnt[group] = 0
for index in range(df.shape[0]):
    race = df.loc[index, 'race/ethnicity']
    score = df.loc[index, 'reading score']
    #print(index, race, score)
    d_sumscore[race] += int(score)
    d_cnt[race] += 1
for race, score in d_sumscore.items():
    print(f'{race}: {score / d_cnt[race]}')
# Out:
# group A: 64.67415730337079
# group B: 67.35263157894737
# group C: 69.10344827586206
# group D: 70.03053435114504
# group E: 73.02857142857142

# %%
# %%timeit
groups = sorted(list(df['race/ethnicity'].unique()))
d_sumscore = {}
d_cnt = {}
for group in groups:
    d_sumscore[group] = 0
    d_cnt[group] = 0
for index in range(df.shape[0]):
    race = df.loc[index, 'race/ethnicity']
    score = df.loc[index, 'reading score']
    #print(index, race, score)
    d_sumscore[race] += int(score)
    d_cnt[race] += 1
for race, score in d_sumscore.items():
    mean_score = score / d_cnt[race]
    #print(f'{race}: {score / d_cnt[race]}')
# Out:
# 20.6 ms ± 2.71 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
#минимальный балл за экзамен по письму для каждого уровня образования
education = sorted(list(df['education'].unique()))
d = {}
for level in education:
    d[level] = 100
for index in range(df.shape[0]):
    level = df.loc[index, 'education']
    score = df.loc[index, 'writing score']
    if score < d[level]:
        d[level] = score
for level, score in d.items():
    print(f'{level}: {score}')
# Out:
# associate's degree: 35
# bachelor's degree: 38
# high school: 15
# master's degree: 46
# some college: 19
# some high school: 10

# %%
#убарала вывод, чтобы много раз не выводил
# %%timeit
education = sorted(list(df['education'].unique()))
d = {}
for level in education:
    d[level] = 100
for index in range(df.shape[0]):
    level = df.loc[index, 'education']
    score = df.loc[index, 'writing score']
    if score < d[level]:
        d[level] = score
#for level, score in d.items():
    #print(f'{level}: {score}')
# Out:
# 18.5 ms ± 351 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# Вывод: группировка с помощью обычных циклов занимает больше времени

# %% [markdown]
# **Задание 13. Выведите на экран средние баллы студентов по каждому предмету в зависимости от пола и уровня образования. То есть должно получиться количество групп, равных 2 * (число уровней образования), и для каждой такой группы выыведите средний балл по каждому из предметов.**
#
# Это можно сделать с помощью сводных таблиц (pivot_table):
#
# https://www.kaggle.com/kamilpolak/tutorial-how-to-use-pivot-table-in-pandas

# %%
import numpy as np

# %%
pd.pivot_table(df,
               index=["gender", "education"],
               values=["math score", 'reading score', 'writing score'],
               aggfunc=np.mean)
# Out:
#                            math score  reading score  writing score
# gender education
# female associate's degree   65.250000      74.120690      74.000000
#        bachelor's degree    68.349206      77.285714      78.380952
#        high school          59.351064      68.202128      66.691489
#        master's degree      66.500000      76.805556      77.638889
#        some college         65.406780      73.550847      74.050847
#        some high school     59.296703      69.109890      68.285714
# male   associate's degree   70.764151      67.433962      65.405660
#        bachelor's degree    70.581818      68.090909      67.654545
#        high school          64.705882      61.480392      58.539216
#        master's degree      74.826087      73.130435      72.608696
#        some college         69.009259      64.990741      63.148148
#        some high school     67.840909      64.693182      61.375000

# %% [markdown]
# #### Задание 14. Сколько студентов успешно сдали экзамен по математике?
#
# Создайте новый столбец в таблице df под названием Math_PassStatus и запишите в него F, если студент не сдал экзамен по математике (балл за экзамен < passmark), и P иначе.
#
# Посчитайте количество студентов, сдавших и не сдавших экзамен по математике.
#
# Сделайте аналогичные шаги для экзаменов по чтению и письму.

# %% [markdown]
# Математика

# %%
df['Math_PassStatus'] = np.where((df['math score'] < passmark), 'F', 'P')
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus
# 0  group1          72             72             74               P
# 1  group1          69             90             88               P
# 2  group1          90             95             93               P
# 3  group1          47             57             44               F
# 4  group1          76             78             75               P

# %%
print('Количество несдавших экзамен по математике:', (df['Math_PassStatus'] == 'F').sum())
print('Количество сдавших экзамен по математике:', (df['Math_PassStatus'] == 'P').sum())
# Out:
# Количество несдавших экзамен по математике: 135
# Количество сдавших экзамен по математике: 865

# %% [markdown]
# Чтение

# %%
df['Reading_PassStatus'] = np.where(df['reading score'] < passmark, 'F', 'P')
print('Количество несдавших экзамен по чтению:', (df['Reading_PassStatus'] == 'F').sum())
print('Количество сдавших экзамен по чтению:', (df['Reading_PassStatus'] == 'P').sum())
# Out:
# Количество несдавших экзамен по чтению: 90
# Количество сдавших экзамен по чтению: 910

# %% [markdown]
# Письмо

# %%
df['Writing_PassStatus'] = np.where(df['writing score'] < passmark, 'F', 'P')
print('Количество несдавших экзамен по письму:', (df['Writing_PassStatus'] == 'F').sum())
print('Количество сдавших экзамен по письму:', (df['Writing_PassStatus'] == 'P').sum())
# Out:
# Количество несдавших экзамен по письму: 114
# Количество сдавших экзамен по письму: 886

# %% [markdown]
# #### Задание 15. Сколько студентов успешно сдали все экзамены?
#
# Создайте столбец OverAll_PassStatus и запишите в него для каждого студента 'F', если студент не сдал хотя бы один из трех экзаменов, а иначе 'P'.
#
# Посчитайте количество студентов, которые сдали все экзамены.

# %%
df['OverAll_PassStatus'] = np.where(((df['writing score'] >= passmark) & (df['reading score'] >= passmark) & (df['math score'] >= passmark)), 'P', 'F')

# %%
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# 0  group1          72             72             74               P
# 1  group1          69             90             88               P
# 2  group1          90             95             93               P
# 3  group1          47             57             44               F
# 4  group1          76             78             75               P
#
#   Reading_PassStatus Writing_PassStatus OverAll_PassStatus
# ...

# %%
print(f'Количество студентов, которые сдали все экзамены:', (df['OverAll_PassStatus'] == 'P').sum())
# Out:
# Количество студентов, которые сдали все экзамены: 812

# %% [markdown]
# #### Задание 16. Переведем баллы в оценки
#
# ### Система перевода баллов в оценки
# ####    больше 90 = A
# ####      80-90 = B
# ####      70-80 = C
# ####      60-70 = D
# ####      50-60 = E
# ####    меньше 50 = F (Fail)
#
# Создайте вспомогательную функцию, которая будет по среднему баллу за три экзамена выставлять оценку студенту по данным выше критериям.
#
# Создайте столбец Grade и запишите в него оценку каждого студента.
#
# Выведите количество студентов, получивших каждую из оценок.
#
# **В случае, если средний балл попадает на границу между оценками (т.е. равен ровно 60, 70 или 80 баллов), вы можете интерпретировать условие на своё усмотрение (т.е. можете поставить за 60 баллов оценку D, а можете - E).**

# %%
def GetGrade(average_mark):
    if average_mark > 90:
        return 'A'
    elif 80 < average_mark <= 90:
        return 'B'
    elif 70 < average_mark <= 80:
        return 'C'
    elif 60 < average_mark <=70:
        return 'D'
    elif 50 <= average_mark <= 60:
        return 'E'
    else:
        return 'F'

# %%
#среднее оценок для каждого студента
df[['math score', 'writing score', 'reading score']].mean(axis = 1)
# Out:
# 0      72.666667
# 1      82.333333
# 2      92.666667
# 3      49.333333
# 4      76.333333
#          ...
# 995    94.000000
# 996    57.333333
# 997    65.000000
# 998    74.333333
# 999    83.000000
# Length: 1000, dtype: float64

# %%
#Создание столбца с оценкой
df['Grade'] = df[['math score', 'writing score', 'reading score']].mean(axis = 1).apply( lambda x: GetGrade(x))

# %%
df.head()
# Out:
#    gender race/ethnicity           education         lunch test preparation  \
# 0  female        group B   bachelor's degree      standard             none
# 1  female        group C        some college      standard        completed
# 2  female        group B     master's degree      standard             none
# 3    male        group A  associate's degree  free/reduced             none
# 4    male        group C        some college      standard             none
#
#     group  math score  reading score  writing score Math_PassStatus  \
# 0  group1          72             72             74               P
# 1  group1          69             90             88               P
# 2  group1          90             95             93               P
# 3  group1          47             57             44               F
# 4  group1          76             78             75               P
#
#   Reading_PassStatus Writing_PassStatus OverAll_PassStatus Grade
# ...

# %%
#Количество студентов, получивших каждую из оценок
df.groupby(['Grade']).agg({'Grade': [len]})
# Out:
#       Grade
#         len
# Grade
# A        50
# B       144
# C       253
# D       260
# E       190
# F       103

# %%
#Второй способ
pd.pivot_table(df,
               index=["Grade"], values = ['gender'],
               aggfunc=len)
# Out:
#        gender
# Grade
# A          50
# B         144
# C         253
# D         260
# E         190
# F         103
